# %% [markdown]
# ### Problema 10

# %% [markdown]
# #### No Problema 2, suponha que 5 indique o aparecimento da face 5 e Q indique que apareceu outra face qualquer diferente de 5. Atribua probabilidade (5/6)^k * (1/6) a cada ponto com k letras iguais a Q seguidas de 5.

# %% [markdown]
# #### (a) Mostre que a soma das probabilidades dos pontos amostrais é igual a um (aqui, você deve usar o resultado da soma dos termos de uma sequência geométrica infinita).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### (b) Calcule a probabilidade de que a face 5 apareça após três lançamentos de dado.

# %%
P_QQ5 = ( (5/6)**2 ) * (1/6)
print('P(QQ5) = ', P_QQ5)
# Out:
# P(QQ5) =  0.11574074074074076
