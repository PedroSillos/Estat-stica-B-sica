# %% [markdown]
# ### Problema 12

# %% [markdown]
# #### Considere o lançamento de dois dados. Considere os eventos A = soma dos números obtidos igual a 9, e B = número no primeiro dado maior ou igual a 4. Enumere os elementos de A e B. Obtenha A U B, A ∩ B e A´.

# %% [markdown]
# A = { (3,6), (4,5), (5,4), (6,3) }
#
# B = { (4,4), (4,5), (4,6), (5,4), (5,5), (5,6), (6,4), (6,5), (6,6) }
#
# A ∩ B = { (4,5), (5,4), (6,3) }
#
# A U B = { (3,6), (4,4), (4,5), (4,6), (5,4), (5,5), (5,6), (6,4), (6,5), (6,6) }

# %% [markdown]
# ![image.png](attachment:image.png)
