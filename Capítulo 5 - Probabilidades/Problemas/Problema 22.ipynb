# %% [markdown]
# ### Problema 22

# %% [markdown]
# #### Supondo que todos os componentes do sistema da figura abaixo tenham a mesma confiabilidade p e funcionem independentemente, obtenha a confiabilidade do sistema.

# %% [markdown]
# ![Sistema%2022.png](attachment:Sistema%2022.png)

# %%
print("P(S) = P( (A1 ∩ A2) U (A3 ∩ A4) )")
print()
print("P( A1 ∩ A2 ) = p*p, pois são independentes")
print()
print("P( A3 ∩ A4 ) = p*p, pois são independentes ")
print()
print("P(S) = P( (A1 ∩ A2) U (A3 ∩ A4) ) = p*p + p*p - (p*p)*(p*p) = p² + p² - p^4 = p²(2 - p²)")
# Out:
# P(S) = P( (A1 ∩ A2) U (A3 ∩ A4) )
#
# P( A1 ∩ A2 ) = p*p, pois são independentes
#
# P( A3 ∩ A4 ) = p*p, pois são independentes
#
# P(S) = P( (A1 ∩ A2) U (A3 ∩ A4) ) = p*p + p*p - (p*p)*(p*p) = p² + p² - p^4 = p²(2 - p²)
