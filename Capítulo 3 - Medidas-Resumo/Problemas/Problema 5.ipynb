# %% [markdown]
# ## Problema 5

# %% [markdown]
# #### Suponha que a variável de interesse tenha a distribuição como na figura abaixo:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Você acha que a média é uma boa medidda de posição? E a mediana? Justifique.

# %% [markdown]
# Tanto a média como a mediana não são boas medidas pois o erro será alto para ambas. Nesse caso seria melhor considerar a(s) moda(s).
