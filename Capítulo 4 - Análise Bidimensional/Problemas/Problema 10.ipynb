# %% [markdown]
# ## Problema 10

# %% [markdown]
# #### Para cada par de variáveis abaixo, esboce o gráfico de dispersão. Diga se você espera uma dependência linear e nos casos afirmativos avalie o coeficiente de correlação.

# %% [markdown]
# ##### (a) Peso e altura dos alunos do primeiro ano de um curso de Administração.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Quanto maior o peso, maior a altura.

# %% [markdown]
# ##### (b) Peso e altura dos funcionários de um escritório.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Quanto maior o peso, maior a altura.

# %% [markdown]
# ##### (c) Quantidade de trigo produzida e quantidade de água recebida por canteiros numa estação experimental.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Quanto mais água, mais trigo.

# %% [markdown]
# ##### (d) Notas de Cálculo e Estatística de uma classe onde as duas disciplinas são lecionadas.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Quanto maior a nota de cálculo, maior a nota de estatística.

# %% [markdown]
# ##### (e) Acuidade visual e idade de um grupo de pessoas.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Quanto maior a idade, menor a acuidade.
