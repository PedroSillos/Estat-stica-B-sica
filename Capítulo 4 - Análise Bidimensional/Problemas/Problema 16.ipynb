# %% [markdown]
# ## Problema 16

# %% [markdown]
# ### Faça o gráfico q x q para as notas em Redação e Economia dos 25 funcionários da MB Indústria e Comércio (Problema 9 do Capítulo 2).

# %%
import pandas as pd
import statistics as stat
import math as math
import matplotlib.pyplot as plt

# %%
df=pd.DataFrame(
    data={
        "Redação":[8.6,7.0,8.0,8.6,8.0,8.5,8.2,7.5,9.4,7.9,8.6,8.3,7.0,8.6,8.6,9.5,6.3,7.6,6.8,7.5,7.7,8.7,7.3,8.5,7.0],
        "Economia":[8.5,8.0,8.5,8.5,9.0,9.5,7.0,8.5,8.0,7.5,8.5,8.0,8.5,7.5,7.0,7.5,7.5,8.5,9.5,8.5,8.0,9.0,7.0,9.0,8.5]
    }
)
df
# Out:
#     Redação  Economia
# 0       8.6       8.5
# 1       7.0       8.0
# 2       8.0       8.5
# 3       8.6       8.5
# 4       8.0       9.0
# 5       8.5       9.5
# 6       8.2       7.0
# 7       7.5       8.5
# 8       9.4       8.0
# 9       7.9       7.5
# 10      8.6       8.5
# 11      8.3       8.0
# 12      7.0       8.5
# 13      8.6       7.5
# 14      8.6       7.0
# 15      9.5       7.5
# 16      6.3       7.5
# 17      7.6       8.5
# 18      6.8       9.5
# 19      7.5       8.5
# 20      7.7       8.0
# 21      8.7       9.0
# 22      7.3       7.0
# 23      8.5       9.0
# 24      7.0       8.5

# %%
df_percentiles = pd.DataFrame(
    data={
        "Redação":[25, 6.0, 7.0, 8.0, 9.0, 10],
        "Economia":[25, 6.0, 7.0, 8.0, 9.0, 10]
    },
    index=['count', '0%', '25%', '50%', '75%', '100%']
)
df_percentiles
# Out:
#        Redação  Economia
# count     25.0      25.0
# 0%         6.0       6.0
# 25%        7.0       7.0
# 50%        8.0       8.0
# 75%        9.0       9.0
# 100%      10.0      10.0

# %%
plt.scatter(df['Redação'].sort_values(axis=0, ascending=True, kind='quicksort'), df['Economia'].sort_values(axis=0, ascending=True, kind='quicksort'), s=None, c=None)

plt.xlim(df_percentiles.at['0%', 'Redação'], df_percentiles.at['100%', 'Redação'])
plt.ylim(df_percentiles.at['0%', 'Economia'], df_percentiles.at['100%', 'Economia'])

plt.show()
